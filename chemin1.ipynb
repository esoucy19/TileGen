# %%
"""
Structure de données:
G = (N,R,V), où:
    - N est l'ensemble des noeuds associés aux points du plan.
    - R est l'ensemble des arêtes du quadtree
    - V est l'ensemble des arêtes reliant les paires de noeuds voisins
"""

class Graphe:
    def __init__(self, N = [], R = [], V = []):
        self.N = N
        self.R = R
        self.V = V
        

class Noeud:
    def __init__(self, visite = False):
        self.visite = visite


class Arete:
    def __init__(self, source = None, destination = None,
                 etiquette = None):
        self.source = source
        self.destination = destination
        self.etiquette = etiquette
        

def initialiser_graphe():
    """
    Crée un graphe initial contenant la racine et ses quatre voisins
    """
    racine = Noeud(visite = True)
    voisinD = Noeud()
    voisinH = Noeud()
    voisinG = Noeud()
    voisinB = Noeud()
    RD = Arete(source = racine, destination = VoisinD,
              etiquette = (1,0))
    VD = Arete(source = racine, destination = VoisinD,
              etiquette = (1,0))
    RH = Arete(source = racine, destination = VoisinH,
              etiquette = (0,1))
    VH = Arete(source = racine, destination = VoisinH,
              etiquette = (0,1))
    RG = Arete(source = racine, destination = VoisinG,
              etiquette = (-1,0))
    VG = Arete(source = racine, destination = VoisinG,
              etiquette = (-1,0))
    RB = Arete(source = racine, destination = VoisinB,
              etiquette = (0,-1))
    VB = Arete(source = racine, destination = VoisinB,
              etiquette = (0,-1))
    return Graphe(N = [racine, voisinD, voisinH, voisinG, voisinB],
                  R = [RD, RH, RG, RB],
                  V = [VD, VH, VG, VB])

def lire_mot(w):
    return None

def trouverVoisin(G, n, a):
    return None
